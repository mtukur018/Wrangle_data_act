# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Introduction
# Real-world data rarely comes clean, because of this it is expected of a data Analyst to go through what's called ``Data wrangling process``. This project is meant to test my abilities in order to ensure that i can pick a dataset from a real world Application Programming Interface (API)  which in this case is a twitter database.
# The dataset I will be analyzing and visualizing is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs, to generate usefull insight and tell a story, let begin!

# %% [markdown]
# ## Data Gathering
#
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
#importing the required packages.
import pandas as pd 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns 
import json
import requests

# %%
twt_data = pd.read_csv('twitter-archive-enhanced-2.csv')

with pd.option_context("display.max_columns", None):
    display(twt_data)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# The above code cell ``prints``(show) the entire Rows and columns in the Dataset.

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Abdurrahman'

# %% [markdown]
# I use the above code to know the exact direcory of the current notebook

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.vscode',
#  'ALx P2 wrangle_act .ipynb',
#  'Alx p3 by Alfred.ipynb',
#  'Alx P3.ipynb',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'df1.csv',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'fav_retweet.png',
#  'image-predictions-3.tsv',
#  'image_predictions.tsv',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New folder',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TM.blf',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Part_II_slide_deck_template (3).ipynb',
# ...

# %% [markdown]
# The listdir() function is a function provided by the os module, and by using this function, we can print a list of names of all the files present in the specified path

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %%
# import tweepy
# from tweepy import OAuthHandler
# import json
# from timeit import default_timer as timer

# # Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# # These are hidden to comply with Twitter's API terms and conditions
# consumer_key = 'HIDDEN'
# consumer_secret = 'HIDDEN'
# access_token = 'HIDDEN'
# access_secret = 'HIDDEN'

# auth = OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_secret)

# api = tweepy.API(auth, wait_on_rate_limit=True)

# # NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# # df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# # change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# # NOTE TO REVIEWER: this student had mobile verification issues so the following
# # Twitter API code was sent to this student from a Udacity instructor
# # Tweet IDs for which to gather additional data via Twitter's API
# tweet_ids = df_1.tweet_id.values
# len(tweet_ids)

# # Query Twitter's API for JSON data for each tweet ID in the Twitter archive
# count = 0
# fails_dict = {}
# start = timer()
# # Save each tweet's returned JSON as a new line in a .txt file
# with open('tweet_json.txt', 'w') as outfile:
#     # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
#     for tweet_id in tweet_ids:
#         count += 1
#         print(str(count) + ": " + str(tweet_id))
#         try:
#             tweet = api.get_status(tweet_id, tweet_mode='extended')
#             print("Success")
#             json.dump(tweet._json, outfile)
#             outfile.write('\n')
#         except tweepy.TweepError as e:
#             print("Fail")
#             fails_dict[tweet_id] = e
#             pass
# end = timer()
# print(end - start)
# print(fails_dict)

# %% [markdown]
# The Code above is the programmatic way of getting data from the Twitter (twitter API),
# I marked the above cell as comment because the code will try to access the twitter API through my developer account which i was unable to activate due to the delayed response from twitter and the limited time that i have to submit my project, Alternatively i would've to use the data provided by UDACITY.

# %%
twt_data = pd.read_csv('twitter-archive-enhanced-2.csv')

# %%
twt_data
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %% [markdown]
# The above code reads through the csv file into the dataframe which was variably named as ``twt_data``

# %% [markdown]
# ## Downloading  the Tweet image predictions file

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

with open('image_predictions.tsv', 'wb') as fl:
    fl.write(response.content)

# %%
#Reading the image prediction file 
twt_sample_img = pd.read_csv('image_predictions.tsv', sep = '\t')
twt_sample_img.sample(3)
# Out:
#                 tweet_id                                          jpg_url  \
# 544   677301033169788928  https://pbs.twimg.com/media/CWZBsjPWsAAZFFl.jpg
# 1694  816091915477250048  https://pbs.twimg.com/media/C1NXQ6NXUAEAxIQ.jpg
# 44    666781792255496192  https://pbs.twimg.com/media/CUDigRXXIAATI_H.jpg
#
#       img_num                 p1   p1_conf  p1_dog          p2   p2_conf  \
# 544         1   Japanese_spaniel  0.661178    True    Pekinese  0.150119
# 1694        3         Pomeranian  0.967345    True     Samoyed  0.007397
# 44          1  Italian_greyhound  0.618316    True  Weimaraner  0.151363
#
#       p2_dog         p3   p3_conf  p3_dog
# 544     True  Chihuahua  0.119720    True
# 1694    True   papillon  0.006017    True
# 44      True     vizsla  0.085989    True

# %% [markdown]
# The above code read the image prediction file and generate 3 random samples as specified in the parametres

# %%
twt_sample_img.loc[1360, :]
# Out:
# tweet_id                                 761004547850530816
# jpg_url     https://pbs.twimg.com/media/Co-hmcYXYAASkiG.jpg
# img_num                                                   1
# p1                                         golden_retriever
# p1_conf                                            0.735163
# p1_dog                                                 True
# p2                                           Sussex_spaniel
# p2_conf                                            0.064897
# p2_dog                                                 True
# p3                                       Labrador_retriever
# p3_conf                                            0.047704
# p3_dog                                                 True
# Name: 1360, dtype: object

# %% [markdown]
# The above codecell locates ``Row 1306`` and print the whole columns in that row, but the random rows might change as this code is rerun again.

# %%
twt_sample_img.loc[1306, 'jpg_url']
# Out:
# 'https://pbs.twimg.com/ext_tw_video_thumb/753398183879991296/pu/img/bqFy5Zc_PEk6Mx-B.jpg'

# %%
from PIL import Image
import requests

# %%
img = Image.open(requests.get(url = 'https://pbs.twimg.com/ext_tw_video_thumb/753398183879991296/pu/img/bqFy5Zc_PEk6Mx-B.jpg',stream=True).raw)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x568 at 0x25AAE3E4370>

# %% [markdown]
# Using ``loc`` code to find the row that i want to extract the url to display the sample image, i had to find its detail and use the ``image requests`` from python image libraries ``PIL`` to display the image.

# %%
#Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)
tweet_list = []

with open('tweet-json.txt') as fl:
    lines = fl.readlines()
    for line in lines:
        json_load = json.loads(line)
        tweet_list.append(json_load)

twt_json = pd.DataFrame(tweet_list)

# %%
twt_json
# Out:
#                           created_at                  id              id_str  \
# 0     Tue Aug 01 16:23:56 +0000 2017  892420643555336193  892420643555336193
# 1     Tue Aug 01 00:17:27 +0000 2017  892177421306343426  892177421306343426
# 2     Mon Jul 31 00:18:03 +0000 2017  891815181378084864  891815181378084864
# 3     Sun Jul 30 15:58:51 +0000 2017  891689557279858688  891689557279858688
# 4     Sat Jul 29 16:00:24 +0000 2017  891327558926688256  891327558926688256
# ...                              ...                 ...                 ...
# 2349  Mon Nov 16 00:24:50 +0000 2015  666049248165822465  666049248165822465
# 2350  Mon Nov 16 00:04:52 +0000 2015  666044226329800704  666044226329800704
# 2351  Sun Nov 15 23:21:54 +0000 2015  666033412701032449  666033412701032449
# 2352  Sun Nov 15 23:05:30 +0000 2015  666029285002620928  666029285002620928
# 2353  Sun Nov 15 22:32:08 +0000 2015  666020888022790149  666020888022790149
#
# ...

# %%
twt_json = pd.DataFrame(twt_json, columns = ['id', 'retweet_count', 'favorite_count'])

# %%
twt_json
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %%
twt_json.to_csv('twt_json.csv',index = False)

# %%
json_data = pd.read_csv('twt_json.csv')
json_data.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %% [markdown]
# ## Assessing Data

# %%
#Accessing the enhanced twitter Archive
twt_data.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# Looking at twt_csv file, i noticed a total of 2356 entries, 17 columns, the dataset has alot of missing or null values, in the columns in columns like;
#
# ``in_reply_to_status_id``
# ``in_reply_to_user_id``
# ``retweeted_status_id``
# ``retweeted_status_user_id``
# ``retweeted_status_time_stamp``
#
# but i will find out more about this data in the data wrangling process, to drop which column(s) are not neccessary for this analysis,

# %%
twt_data.rating_numerator.describe()
# Out:
# count    2356.000000
# mean       13.126486
# std        45.876648
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        12.000000
# max      1776.000000
# Name: rating_numerator, dtype: float64

# %%
twt_data[twt_data.rating_numerator < 10].count()[0]
# Out:
# 440

# %%
twt_data[twt_data.rating_numerator < 10].tweet_id
# Out:
# 45      883482846933004288
# 229     848212111729840128
# 315     835152434251116546
# 387     826598799820865537
# 462     817502432452313088
#                ...
# 2351    666049248165822465
# 2352    666044226329800704
# 2353    666033412701032449
# 2354    666029285002620928
# 2355    666020888022790149
# Name: tweet_id, Length: 440, dtype: int64

# %%
twt_data.loc[2351, 'text']
# Out:
# 'Here we have a 1949 1st generation vulpix. Enjoys sweat tea and Fox News. Cannot be phased. 5/10 https://t.co/4B7cOc1EDq'

# %%
twt_data.rating_denominator.describe()
# Out:
# count    2356.000000
# mean       10.455433
# std         6.745237
# min         0.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max       170.000000
# Name: rating_denominator, dtype: float64

# %%
# Looking for possibilty of having 0 value in denominator_rating

twt_data[twt_data.rating_denominator == 0].tweet_id
# Out:
# 313    835246439529840640
# Name: tweet_id, dtype: int64

# %%
twt_data.loc[313, 'text']
# Out:
# "@jonnysun @Lin_Manuel ok jomny I know you're excited but 960/00 isn't a valid rating, 13/10 is tho"

# %% [markdown]
# Looking further to locate the above cell i observed that the rating that was giving by @jonnysun was wrong and @Lin_manuel was trying to correct him that the valid rating should be 13/10.

# %%
twt_data.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
#              ...
# Dex             1
# Ace             1
# Tayzie          1
# Grizzie         1
# Christoper      1
# Name: name, Length: 957, dtype: int64

# %%
#Getting the first few rows of twitter Api json file
twt_json.head(6)
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
# 5  891087950875897856           3261           20562

# %%
twt_json.sample(15)
# Out:
#                       id  retweet_count  favorite_count
# 708   785170936622350336           5639           13491
# 187   855862651834028034             27             320
# 2147  669684865554620416             99             551
# 699   786233965241827333           5571           17178
# 1842  675849018447167488            172            1027
# 825   769212283578875904           1969            5980
# 2350  666044226329800704            147             311
# 1797  677187300187611136           1033            2981
# 2309  666781792255496192            211             404
# 1914  674307341513269249           7641           12129
# 1976  672984142909456390            593            1338
# 2204  668631377374486528            349             763
# 675   789314372632018944           2666            9615
# 1069  740214038584557568           2220            7335
# 1453  695409464418041856           4017            9460

# %%
img_1 = pd.read_csv('image_predictions.tsv', sep='\t')
img_1.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# Trying to Access the image prediction Dataset which i named variably as ``img_1``.

# %%
img_1.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 863   697259378236399616    https://pbs.twimg.com/media/Ca0ps3AXEAAnp9m.jpg
# 991   708026248782585858  https://pbs.twimg.com/ext_tw_video_thumb/70802...
# 426   674082852460433408    https://pbs.twimg.com/media/CVrSxy7WsAAFD2F.jpg
# 377   673213039743795200    https://pbs.twimg.com/media/CVe7r7QVEAAc4Bg.jpg
# 1523  788150585577050112    https://pbs.twimg.com/media/CvASw6dWcAQmo3X.jpg
# 921   701981390485725185    https://pbs.twimg.com/media/Cb3wWWbWEAAy06k.jpg
# 1390  766693177336135680    https://pbs.twimg.com/media/CqPXYLLXEAAU2HC.jpg
# 194   669573570759163904    https://pbs.twimg.com/media/CUrNmtFWoAAnWCD.jpg
# 765   689143371370250240    https://pbs.twimg.com/media/CZBUO2UWsAAKehS.jpg
# 1532  789628658055020548    https://pbs.twimg.com/media/CvVTEnPXYAAWLyL.jpg
#
#       img_num                           p1   p1_conf  p1_dog  \
# 863         1                   Great_Dane  0.999223    True
# ...

# %%
img_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
#  The ``info()`` function is used to print a concise summary of a DataFrame(``imag_1``). This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
#Summary stats of each Dataset
twt_data.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
img_1.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
twt_json.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %% [markdown]
# The ``describe()``method returns description of the data in the DataFrame. If the DataFrame contains numerical data, the description contains these information for each column: count - The number of not-empty values. mean - The average (mean) value.

# %%
twt_data.duplicated().sum()
# Out:
# 0

# %%
twt_json.duplicated().sum()
# Out:
# 0

# %%
img_1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# looks like we have no duplicate in the datasets

# %%
twt_data.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
# ...

# %% [markdown]
# The unique() function is used to get unique values of Series object.

# %%
twt_data.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
#              ...
# Dex             1
# Ace             1
# Tayzie          1
# Grizzie         1
# Christoper      1
# Name: name, Length: 957, dtype: int64

# %%
twt_data.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
twt_json.head()
# Out:
#                    id  retweet_count  favorite_count
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048

# %%
twt_sample_img.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
twt_sample_img.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
twt_data_copy = twt_data.copy(deep = True)
twt_json_copy = twt_json.copy(deep = True)
twt_sample_img_copy = twt_sample_img.copy(deep = True)

# %%
twt_data_copy
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# ...

# %%
twt_sample_img_copy
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# ...

# %%
twt_json_copy
# Out:
#                       id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %% [markdown]
# ### Quality issues
# 1. twt_data: Timestap columns is an object type instead of datetime.
#
# 2. twt_data: tweet id column datatype displays int64 instead,it should be an object
#
#
# 3. twt_sample_img: columns such as ('p1', 'p2', 'p1_config', 'p2_config'. etc.) dont have descriptive titles.
#
# 4. twt_json: the id should have the same name as tweet_id for consistency when merging the datasets.
#
# 5. twt_data: Columns ('doggo', 'puppo', 'floofer, 'pupper') has None for missing Values.
#
# 6. twt_data: 'Names' columns has None values instead of 'NAN' and too many invalid values.
#
# 7. there are 181 retweets as showed by retweeted_status_id
#
# 8. twt_data: Name columns consists of names with upper case letters.
# 9. Rating numerators less than 10 should be looked into

# %% [markdown]
# ### Tidiness issues
# 1.twt_csv and twt_json should be merged in twt_csv
#
# 2.twt_csv(twt_data):  the columns ``('doggo', 'floofer', 'pupper', 'puppo')`` should be merge in a single column for better analysis.

# %% [markdown]
# ### Issue #1:

# %% [markdown]
# #### Define
# This code will convert Timestamp column Dtype to datetime

# %% [markdown]
# #### Code

# %%
twt_data_copy ['timestamp'] = pd.to_datetime(twt_data_copy ['timestamp'])

# %% [markdown]
# #### Test

# %%
twt_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns, UTC]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# #### Define:
# changing tweet id Dtype from int64 to object

# %% [markdown]
# #### Code

# %%
twt_sample_img_copy['tweet_id'] = twt_sample_img_copy['tweet_id'].astype('object')

# %% [markdown]
# #### Test

# %%
twt_sample_img_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# ## Issue # 3

# %% [markdown]
# #### Define: Making  the column(s) title  ( p1,  p1_conf ,  p2 ,  p2_conf ,  p3 ,  p3_conf, ....)  descriptive

# %% [markdown]
# #### Code

# %%
twt_sample_img_copy.rename (columns={'p1':       'prediction_1',
                   'p1_conf':  'prediction_1_confidence',
                   'p1_dog':   'prediction_1_dog',
                   'p2':       'prediction_2',
                   'p2_conf':  'prediction_2_confidence',
                   'p2_dog':   'prediction_2_dog',
                   'p3':       'prediction_3',
                   'p3_conf':  'prediction_3_confidence',
                   'p3_dog':   'prediction_3_dog' },
          inplace=True)

# %% [markdown]
# #### Test

# %%
twt_sample_img_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 2075 non-null   object
#  1   jpg_url                  2075 non-null   object
#  2   img_num                  2075 non-null   int64
#  3   prediction_1             2075 non-null   object
#  4   prediction_1_confidence  2075 non-null   float64
#  5   prediction_1_dog         2075 non-null   bool
#  6   prediction_2             2075 non-null   object
#  7   prediction_2_confidence  2075 non-null   float64
#  8   prediction_2_dog         2075 non-null   bool
#  9   prediction_3             2075 non-null   object
#  10  prediction_3_confidence  2075 non-null   float64
#  11  prediction_3_dog         2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %%
twt_sample_img_copy.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'prediction_1',
#        'prediction_1_confidence', 'prediction_1_dog', 'prediction_2',
#        'prediction_2_confidence', 'prediction_2_dog', 'prediction_3',
#        'prediction_3_confidence', 'prediction_3_dog'],
#       dtype='object')

# %% [markdown]
# ## Issue 4

# %% [markdown]
# #### Define: Merging column names for consistent analysis

# %% [markdown]
# #### Code

# %%
twt_json_copy.rename(columns= {'id' : 'tweet_id'},
            inplace = True, errors = 'raise')

# %%
twt_json_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %% [markdown]
# ## Issue 5

# %% [markdown]
# #### Define: Replacing all missing values in column(s) like ('doggo', 'pupper, 'floffer', 'puppo') with 'NAN'

# %% [markdown]
# #### Code

# %%
twt_data_copy = pd.read_csv('twitter-archive-enhanced-2.csv')


column_list = ['doggo', 'floofer',  'pupper', 'puppo']

for col in column_list:
    twt_data_copy[col] = twt_data_copy[col].replace('None', np.nan)

# %% [markdown]
# #### Test

# %%
twt_data_copy.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ## Issue 6

# %% [markdown]
# #### Define: checking for the column names with missing values and invalid values

# %% [markdown]
# #### Code

# %%
title = twt_data_copy['name'].str.islower()
col = 'name'
twt_data_copy.loc[title, col] = np.nan
twt_data_copy.replace('None', np.nan, inplace = True)

# %% [markdown]
# #### Test

# %%
twt_data_copy.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ## Issue 7

# %% [markdown]
# #### Define: dropping all retweets column

# %%
twt_data_copy.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
twt_data_copy = twt_data_copy.drop(columns =['retweeted_status_id',
    'retweeted_status_user_id',  
    'retweeted_status_timestamp'])

# %%
twt_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2356 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2356 non-null   object
#  4   source                 2356 non-null   object
#  5   text                   2356 non-null   object
#  6   expanded_urls          2297 non-null   object
#  7   rating_numerator       2356 non-null   int64
#  8   rating_denominator     2356 non-null   int64
#  9   name                   1502 non-null   object
#  10  doggo                  97 non-null     object
#  11  floofer                10 non-null     object
#  12  pupper                 257 non-null    object
#  13  puppo                  30 non-null     object
# dtypes: float64(2), int64(3), object(9)
# ...

# %% [markdown]
# ## Issue 8

# %% [markdown]
# #### Define: changing names with small letters

# %% [markdown]
# Code

# %%
twt_data_copy['name'].str.islower()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2351      NaN
# 2352      NaN
# 2353      NaN
# 2354      NaN
# 2355      NaN
# Name: name, Length: 2356, dtype: object

# %% [markdown]
# #### Test

# %%
twt_data_copy.name
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351         NaN
# 2352         NaN
# 2353         NaN
# 2354         NaN
# 2355         NaN
# Name: name, Length: 2356, dtype: object

# %% [markdown]
# ## Tidiness issues

# %% [markdown]
# #### Define:
# Merging 4 columns into 1 column with the title ``(dog_breeds)``

# %%
twt_data_copy.text
# Out:
# 0       This is Phineas. He's a mystical boy. Only eve...
# 1       This is Tilly. She's just checking pup on you....
# 2       This is Archie. He is a rare Norwegian Pouncin...
# 3       This is Darla. She commenced a snooze mid meal...
# 4       This is Franklin. He would like you to stop ca...
#                               ...
# 2351    Here we have a 1949 1st generation vulpix. Enj...
# 2352    This is a purebred Piers Morgan. Loves to Netf...
# 2353    Here is a very happy pup. Big fan of well-main...
# 2354    This is a western brown Mitsubishi terrier. Up...
# 2355    Here we have a Japanese Irish Setter. Lost eye...
# Name: text, Length: 2356, dtype: object

# %%
twt_data_copy.pupper.replace('None','', inplace = True)
twt_data_copy.puppo.replace('None','', inplace = True)
twt_data_copy.doggo.replace('None','', inplace = True)
twt_data_copy.floofer.replace('None','', inplace = True)

# %%
twt_data_copy['dog_breeds'] = twt_data_copy.doggo + twt_data_copy.floofer + twt_data_copy.pupper + twt_data_copy.puppo

# %%
twt_data_copy = twt_data_copy.drop(columns =['doggo','floofer', 'puppo','pupper'])

# %%
twt_data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2356 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2356 non-null   object
#  4   source                 2356 non-null   object
#  5   text                   2356 non-null   object
#  6   expanded_urls          2297 non-null   object
#  7   rating_numerator       2356 non-null   int64
#  8   rating_denominator     2356 non-null   int64
#  9   name                   1502 non-null   object
#  10  dog_breeds             0 non-null      object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 202.6+ KB

# %%
twt_data_copy.dog_breeds.value_counts()
# Out:
# Series([], Name: dog_breeds, dtype: int64)

# %%
twt_data_copy.head(7)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# 6  2017-07-28 16:27:12 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# ...

# %% [markdown]
# ## Tidiness issue 2

# %% [markdown]
# #### Define: Dropping  image number column

# %%
twt_sample_img_copy.drop('img_num', axis=1, inplace = True)

# %%
twt_sample_img_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 2075 non-null   object
#  1   jpg_url                  2075 non-null   object
#  2   prediction_1             2075 non-null   object
#  3   prediction_1_confidence  2075 non-null   float64
#  4   prediction_1_dog         2075 non-null   bool
#  5   prediction_2             2075 non-null   object
#  6   prediction_2_confidence  2075 non-null   float64
#  7   prediction_2_dog         2075 non-null   bool
#  8   prediction_3             2075 non-null   object
#  9   prediction_3_confidence  2075 non-null   float64
#  10  prediction_3_dog         2075 non-null   bool
# dtypes: bool(3), float64(3), object(5)
# memory usage: 135.9+ KB

# %%
merged_data = pd.merge(twt_data_copy, twt_json_copy,on = 'tweet_id', how = 'left').merge(twt_sample_img_copy, on='tweet_id', how='inner' )

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_id               2356 non-null   int64
#  1   in_reply_to_status_id  78 non-null     float64
#  2   in_reply_to_user_id    78 non-null     float64
#  3   timestamp              2356 non-null   object
#  4   source                 2356 non-null   object
#  5   text                   2356 non-null   object
#  6   expanded_urls          2297 non-null   object
#  7   rating_numerator       2356 non-null   int64
#  8   rating_denominator     2356 non-null   int64
#  9   name                   1502 non-null   object
#  10  dog_breeds             0 non-null      object
#  11  retweet_count          2354 non-null   float64
#  12  favorite_count         2354 non-null   float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 257.7+ KB

# %% [markdown]
# ## Storing Data

# %%
merged_data.to_csv('twitter_master_archive,csv', index = False)

# %%
df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'dog_breeds'],
#       dtype='object')

# %% [markdown]
# ## Analyzing and Visualizing Data

# %% [markdown]
# ### Visualization

# %%
twt_json_copy.plot(kind='scatter', x='favorite_count', y='retweet_count')
plt.title('Favorite Count V.S. Retweet Count')
plt.savefig('fav_retweet.png');

# %% [markdown]
# ### Insights:
#  the insight gained from the above graph plotted with Mathplotlib indicates that there is a positive relationship (correlation) between the two variables Favourite count and Retweet count

# %%
#Ordered_count = merged_data['retweet'].value_counts()[:20]

# %%
plt.figure(figsize=(15,10))
sns.set(style="white")
sns.boxplot(x='retweet_count', y="favorite_count", data = merged_data).set_title('box plot')
plt.savefig('stag_fav.png');
